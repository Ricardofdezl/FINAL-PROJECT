# %%
import pandas as pd

# %%
sql_brands = pd.read_csv("SQL PROJECT(brands).csv")
sql_brands
# Out:
#                                              size promotion category  price  \
# 0    UK 4,UK 6,UK 8,UK 10,UK 12,UK 14,UK 16,UK 18        No    Shoes  110.0
# 1    UK 4,UK 6,UK 8,UK 10,UK 12,UK 14,UK 16,UK 18        No    Shoes  140.0
# 2    UK 4,UK 6,UK 8,UK 10,UK 12,UK 14,UK 16,UK 18        No    Shoes  200.0
# 3    UK 4,UK 6,UK 8,UK 10,UK 12,UK 14,UK 16,UK 18        No    Shoes  110.0
# 4    UK 4,UK 6,UK 8,UK 10,UK 12,UK 14,UK 16,UK 18        No    Shoes  110.0
# ..                                            ...       ...      ...    ...
# 834  UK 4,UK 6,UK 8,UK 10,UK 12,UK 14,UK 16,UK 18        No    Shoes  150.0
# 835  UK 4,UK 6,UK 8,UK 10,UK 12,UK 14,UK 16,UK 18        No    Shoes  150.0
# 836  UK 4,UK 6,UK 8,UK 10,UK 12,UK 14,UK 16,UK 18        No    Shoes  150.0
# 837  UK 4,UK 6,UK 8,UK 10,UK 12,UK 14,UK 16,UK 18        No    Shoes  150.0
# 838  UK 4,UK 6,UK 8,UK 10,UK 12,UK 14,UK 16,UK 18        No    Shoes  150.0
#
#      basic_color product_id section  \
# ...

# %%
sql_predictions = pd.read_csv("SQL PROJECT(pred).csv")
sql_predictions
# Out:
#        Actual Price  Predicted Price
# 0         42.355932        42.355764
# 1         50.830508        50.830338
# 2         19.500000        19.457917
# 3         25.406780        25.407003
# 4         33.067797        32.996655
# ...             ...              ...
# 20285     22.016949        22.017005
# 20286     25.406780        25.407211
# 20287     84.728814        84.729527
# 20288     50.830508        50.830338
# 20289     47.830508        47.869651
#
# [20290 rows x 2 columns]
